# %% [markdown]
# # Architecture B

# %%
import os
import sys
import subprocess
import pathlib

REPO_URL = "https://github.com/LLM4SE-group-15/ArchitecturesForCodeDevelopmentWithLLMs.git"
REPO_DIR = pathlib.Path("/content/ArchitecturesForCodeDevelopmentWithLLMs")

if not REPO_DIR.exists():
    subprocess.run(["git", "clone", REPO_URL, str(REPO_DIR)], check=True)

os.chdir(REPO_DIR)
subprocess.run([sys.executable, "-m", "pip", "install", "-U", "pip"], check=True)
subprocess.run([sys.executable, "-m", "pip", "install", "-r", "requirements.txt"], check=True)

print(f"Using repo at {REPO_DIR.resolve()}")
# Out:
# Using repo at /content/ArchitecturesForCodeDevelopmentWithLLMs

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: langchain>=0.1.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (1.2.4)
# Requirement already satisfied: langchain-huggingface>=0.0.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (1.2.0)
# Requirement already satisfied: langgraph>=0.0.20 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (1.0.6)
# Requirement already satisfied: langsmith>=0.0.70 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (0.6.4)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 8)) (0.36.0)
# Requirement already satisfied: transformers>=4.36.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 9)) (4.57.6)
# Requirement already satisfied: datasets==2.21.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 10)) (2.21.0)
# Requirement already satisfied: radon>=6.0.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 13)) (6.0.1)
# Requirement already satisfied: pylint>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 14)) (4.0.4)
# Requirement already satisfied: flake8>=7.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 15)) (7.3.0)
# Requirement already satisfied: black>=23.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 16)) (26.1.0)
# Requirement already satisfied: pytest>=7.4.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 19)) (8.4.2)
# Requirement already satisfied: pytest-cov>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 20)) (7.0.0)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 23)) (2.2.2)
# Requirement already satisfied: numpy>=1.24.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 24)) (2.0.2)
# Requirement already satisfied: matplotlib>=3.7.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 25)) (3.10.0)
# Requirement already satisfied: seaborn>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 26)) (0.13.2)
# Requirement already satisfied: python-dotenv>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 29)) (1.2.1)
# Requirement already satisfied: pydantic>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 30)) (2.12.3)
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 31)) (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets==2.21.0->-r requirements.txt (line 10)) (3.20.3)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets==2.21.0->-r requirements.txt (line 10)) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets==2.21.0->-r requirements.txt (line 10)) (0.3.8)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets==2.21.0->-r requirements.txt (line 10)) (2.32.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets==2.21.0->-r requirements.txt (line 10)) (3.6.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.12/dist-packages (from datasets==2.21.0->-r requirements.txt (line 10)) (0.70.16)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets==2.21.0->-r requirements.txt (line 10)) (2024.6.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from datasets==2.21.0->-r requirements.txt (line 10)) (3.13.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from datasets==2.21.0->-r requirements.txt (line 10)) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets==2.21.0->-r requirements.txt (line 10)) (6.0.3)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.1 in /usr/local/lib/python3.12/dist-packages (from langchain>=0.1.0->-r requirements.txt (line 2)) (1.2.7)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from langgraph>=0.0.20->-r requirements.txt (line 4)) (4.0.0)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in /usr/local/lib/python3.12/dist-packages (from langgraph>=0.0.20->-r requirements.txt (line 4)) (1.0.6)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from langgraph>=0.0.20->-r requirements.txt (line 4)) (0.3.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0.0->-r requirements.txt (line 30)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0.0->-r requirements.txt (line 30)) (2.41.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0.0->-r requirements.txt (line 30)) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0.0->-r requirements.txt (line 30)) (0.4.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.1->langchain>=0.1.0->-r requirements.txt (line 2)) (1.33)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.1->langchain>=0.1.0->-r requirements.txt (line 2)) (9.1.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.1->langchain>=0.1.0->-r requirements.txt (line 2)) (0.13.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.0.70->-r requirements.txt (line 5)) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.0.70->-r requirements.txt (line 5)) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.0.70->-r requirements.txt (line 5)) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.0.70->-r requirements.txt (line 5)) (0.25.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith>=0.0.70->-r requirements.txt (line 5)) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith>=0.0.70->-r requirements.txt (line 5)) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith>=0.0.70->-r requirements.txt (line 5)) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith>=0.0.70->-r requirements.txt (line 5)) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.0.70->-r requirements.txt (line 5)) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.1->langchain>=0.1.0->-r requirements.txt (line 2)) (3.0.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph>=0.0.20->-r requirements.txt (line 4)) (1.12.1)
# Requirement already satisfied: tokenizers<1.0.0,>=0.19.1 in /usr/local/lib/python3.12/dist-packages (from langchain-huggingface>=0.0.3->-r requirements.txt (line 3)) (0.22.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->-r requirements.txt (line 8)) (1.2.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.36.0->-r requirements.txt (line 9)) (2025.11.3)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.36.0->-r requirements.txt (line 9)) (0.7.0)
# Requirement already satisfied: mando<0.8,>=0.6 in /usr/local/lib/python3.12/dist-packages (from radon>=6.0.1->-r requirements.txt (line 13)) (0.7.1)
# Requirement already satisfied: colorama>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from radon>=6.0.1->-r requirements.txt (line 13)) (0.4.6)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from mando<0.8,>=0.6->radon>=6.0.1->-r requirements.txt (line 13)) (1.17.0)
# Requirement already satisfied: astroid<=4.1.dev0,>=4.0.2 in /usr/local/lib/python3.12/dist-packages (from pylint>=3.0.0->-r requirements.txt (line 14)) (4.0.3)
# Requirement already satisfied: isort!=5.13,<8,>=5 in /usr/local/lib/python3.12/dist-packages (from pylint>=3.0.0->-r requirements.txt (line 14)) (7.0.0)
# Requirement already satisfied: mccabe<0.8,>=0.6 in /usr/local/lib/python3.12/dist-packages (from pylint>=3.0.0->-r requirements.txt (line 14)) (0.7.0)
# Requirement already satisfied: platformdirs>=2.2 in /usr/local/lib/python3.12/dist-packages (from pylint>=3.0.0->-r requirements.txt (line 14)) (4.5.1)
# Requirement already satisfied: tomlkit>=0.10.1 in /usr/local/lib/python3.12/dist-packages (from pylint>=3.0.0->-r requirements.txt (line 14)) (0.13.3)
# Requirement already satisfied: pycodestyle<2.15.0,>=2.14.0 in /usr/local/lib/python3.12/dist-packages (from flake8>=7.0.0->-r requirements.txt (line 15)) (2.14.0)
# Requirement already satisfied: pyflakes<3.5.0,>=3.4.0 in /usr/local/lib/python3.12/dist-packages (from flake8>=7.0.0->-r requirements.txt (line 15)) (3.4.0)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from black>=23.0.0->-r requirements.txt (line 16)) (8.3.1)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from black>=23.0.0->-r requirements.txt (line 16)) (1.1.0)
# Requirement already satisfied: pathspec>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from black>=23.0.0->-r requirements.txt (line 16)) (1.0.3)
# Requirement already satisfied: pytokens>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from black>=23.0.0->-r requirements.txt (line 16)) (0.4.0)
# Requirement already satisfied: iniconfig>=1 in /usr/local/lib/python3.12/dist-packages (from pytest>=7.4.0->-r requirements.txt (line 19)) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.12/dist-packages (from pytest>=7.4.0->-r requirements.txt (line 19)) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from pytest>=7.4.0->-r requirements.txt (line 19)) (2.19.2)
# Requirement already satisfied: coverage>=7.10.6 in /usr/local/lib/python3.12/dist-packages (from coverage[toml]>=7.10.6->pytest-cov>=4.1.0->-r requirements.txt (line 20)) (7.13.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->-r requirements.txt (line 23)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->-r requirements.txt (line 23)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->-r requirements.txt (line 23)) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->-r requirements.txt (line 25)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->-r requirements.txt (line 25)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->-r requirements.txt (line 25)) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->-r requirements.txt (line 25)) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->-r requirements.txt (line 25)) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->-r requirements.txt (line 25)) (3.3.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==2.21.0->-r requirements.txt (line 10)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==2.21.0->-r requirements.txt (line 10)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==2.21.0->-r requirements.txt (line 10)) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==2.21.0->-r requirements.txt (line 10)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==2.21.0->-r requirements.txt (line 10)) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==2.21.0->-r requirements.txt (line 10)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==2.21.0->-r requirements.txt (line 10)) (1.22.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets==2.21.0->-r requirements.txt (line 10)) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets==2.21.0->-r requirements.txt (line 10)) (2.5.0)

# %%
import os
import getpass
from huggingface_hub import login

# Forza sempre l'uso del token che inserisci
os.environ["HF_TOKEN"] = getpass.getpass("Enter HF_TOKEN (kept hidden): ")

login(token=os.environ["HF_TOKEN"], add_to_git_credential=False)

os.environ["ARCHITECTURE"] = "B"
print("ARCHITECTURE set to", os.environ["ARCHITECTURE"])
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# WARNING:huggingface_hub._login:Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# ARCHITECTURE set to B

# %%
from huggingface_hub import HfApi

api = HfApi()
try:
    user_info = api.whoami(token=os.environ["HF_TOKEN"])
    print("Logged in to Hugging Face as:", user_info.get("name") or user_info.get("user"))
except Exception as exc:
    print("Login check failed:", exc)
# Out:
# Logged in to Hugging Face as: Riaburger

# %%
import json
import time
import logging
import pathlib
import os

from datetime import datetime

DEFAULT_ROOT = pathlib.Path("/content/ArchitecturesForCodeDevelopmentWithLLMs")
ROOT = DEFAULT_ROOT if DEFAULT_ROOT.exists() else pathlib.Path.cwd()

sys.path.insert(0, str(ROOT))

LOG_DIR = ROOT / "log"
LOG_DIR.mkdir(exist_ok=True)

logger = logging.getLogger("architecture_B")
logger.setLevel(logging.INFO)
if logger.handlers:
    logger.handlers.clear()
formatter = logging.Formatter("%(asctime)s | %(levelname)s | %(message)s")
file_handler = logging.FileHandler(LOG_DIR / "architecture_B.log")
stream_handler = logging.StreamHandler()
for handler in (file_handler, stream_handler):
    handler.setFormatter(formatter)
    logger.addHandler(handler)

logger.info("Logger ready. Repo root: %s", ROOT)
logger.info("Log files: %s", LOG_DIR)
print("Logs ->", LOG_DIR)
# Out:
# 2026-01-22 23:23:05,658 | INFO | Logger ready. Repo root: /content/ArchitecturesForCodeDevelopmentWithLLMs
# INFO:architecture_B:Logger ready. Repo root: /content/ArchitecturesForCodeDevelopmentWithLLMs
# 2026-01-22 23:23:05,661 | INFO | Log files: /content/ArchitecturesForCodeDevelopmentWithLLMs/log
# INFO:architecture_B:Log files: /content/ArchitecturesForCodeDevelopmentWithLLMs/log
# Logs -> /content/ArchitecturesForCodeDevelopmentWithLLMs/log

# %%
import time
import json
from src.data.task_loader import APPSTaskLoader
from src.graph.graph import run_graph
from src.agents.llm import Architecture

ARCH = Architecture.B
SEED_FIXED = 0

def run_sample_tasks(
    per_level: int = 5,
    split: str = "test",
    difficulties: tuple[str, ...] = ("introductory", "interview", "competition"),
    shuffle: bool = True,
):
    loader = APPSTaskLoader(split=split)
    if shuffle:
        # Nota: APPSTaskLoader potrebbe non esporre direttamente _dataset o shuffle in questo modo
        # Assumiamo che il metodo shuffle funzioni come nello snippet originale dell'utente
        if hasattr(loader, "_dataset"):
             loader._dataset = loader.dataset.shuffle(seed=SEED_FIXED)
             
    tasks = []
    for diff in difficulties:
        tasks.extend(loader.load_by_difficulty(diff, limit=per_level))

    results = []
    total = len(tasks)
    logger.info("Loaded %s tasks (%s per difficulty: %s)", total, per_level, ", ".join(difficulties))
    print(f"Starting benchmark on {total} tasks...")
    
    for idx, task in enumerate(tasks, 1):
        logger.info("Running %s/%s %s (%s)", idx, total, task.task_id, task.difficulty)
        # Stampiamo a video solo una riga di 'status' per non intasare l'output
        print(f"[{idx}/{total}] Task {task.task_id} ({task.difficulty})... ", end="", flush=True)
        
        start = time.time()
        # Eseguiamo il grafo per il task corrente
        state = run_graph(
            task_id=task.task_id,
            task_description=task.question,
            test_inputs=task.inputs,
            test_outputs=task.outputs,
            architecture=ARCH,
        )

        elapsed = time.time() - start
        
        # Prepariamo il record
        record = {
            "task_id": task.task_id,
            "difficulty": task.difficulty,
            "architecture": str(ARCH.value),
            "test_passed": state["test_passed"],
            "developer_tier": state.get("developer_tier"),
            "escalations": state["escalations"],
            "story_points_initial": state.get("story_points_initial"),
            "story_points_final": state.get("story_points_current"),
            "elapsed_seconds": elapsed,
        }
        results.append(record)
        
        # Logghiamo info e completiamo la riga di output a video
        logger.info(
            "Finished %s | pass=%s tier=%s escalations=%s elapsed=%.1fs",
            task.task_id,
            state["test_passed"],
            record["developer_tier"],
            record["escalations"],
            elapsed,
        )
        status_str = "PASS" if state["test_passed"] else "FAIL"
        print(f"{status_str} in {elapsed:.1f}s")

        # Scriviamo nel file jsonl
        with open(LOG_DIR / "architecture_B.jsonl", "a", encoding="utf-8") as f:
            f.write(json.dumps(record) + "\n")
            
    return results

# Esecuzione
sample_results = run_sample_tasks(per_level=5, difficulties=("introductory", "interview", "competition"), shuffle=True)

# Visualizziamo solo un sommario finale dei risultati invece dell'intera lista
passed_count = sum(1 for r in sample_results if r['test_passed'])
print(f"\nBenchmark Completed. Passed: {passed_count}/{len(sample_results)}")
# Out:
# Loading APPS dataset (test split)...
# 2026-01-22 23:23:08,567 | INFO | Loaded 15 tasks (5 per difficulty: introductory, interview, competition)
# INFO:architecture_B:Loaded 15 tasks (5 per difficulty: introductory, interview, competition)
# 2026-01-22 23:23:08,570 | INFO | Running 1/15 apps_4662 (introductory)
# INFO:architecture_B:Running 1/15 apps_4662 (introductory)
# Loaded 5000 tasks.
# Starting benchmark on 15 tasks...
# [1/15] Task apps_4662 (introductory)...
# 2026-01-22 23:23:29,750 | INFO | Finished apps_4662 | pass=False tier=L escalations=1 elapsed=21.2s
# INFO:architecture_B:Finished apps_4662 | pass=False tier=L escalations=1 elapsed=21.2s
# 2026-01-22 23:23:29,752 | INFO | Running 2/15 apps_4471 (introductory)
# INFO:architecture_B:Running 2/15 apps_4471 (introductory)
# FAIL in 21.2s
# [2/15] Task apps_4471 (introductory)...
# 2026-01-22 23:24:53,698 | INFO | Finished apps_4471 | pass=False tier=L escalations=1 elapsed=83.9s
# INFO:architecture_B:Finished apps_4471 | pass=False tier=L escalations=1 elapsed=83.9s
# 2026-01-22 23:24:53,700 | INFO | Running 3/15 apps_4982 (introductory)
# INFO:architecture_B:Running 3/15 apps_4982 (introductory)
# FAIL in 83.9s
# [3/15] Task apps_4982 (introductory)...
# 2026-01-22 23:25:36,097 | INFO | Finished apps_4982 | pass=False tier=L escalations=1 elapsed=42.4s
# INFO:architecture_B:Finished apps_4982 | pass=False tier=L escalations=1 elapsed=42.4s
# 2026-01-22 23:25:36,099 | INFO | Running 4/15 apps_4918 (introductory)
# INFO:architecture_B:Running 4/15 apps_4918 (introductory)
# FAIL in 42.4s
# [4/15] Task apps_4918 (introductory)...
# 2026-01-22 23:26:10,524 | INFO | Finished apps_4918 | pass=False tier=L escalations=1 elapsed=34.4s
# INFO:architecture_B:Finished apps_4918 | pass=False tier=L escalations=1 elapsed=34.4s
# 2026-01-22 23:26:10,526 | INFO | Running 5/15 apps_4108 (introductory)
# INFO:architecture_B:Running 5/15 apps_4108 (introductory)
# FAIL in 34.4s
# [5/15] Task apps_4108 (introductory)...
# 2026-01-22 23:26:35,184 | INFO | Finished apps_4108 | pass=False tier=L escalations=1 elapsed=24.7s
# INFO:architecture_B:Finished apps_4108 | pass=False tier=L escalations=1 elapsed=24.7s
# 2026-01-22 23:26:35,188 | INFO | Running 6/15 apps_2221 (interview)
# INFO:architecture_B:Running 6/15 apps_2221 (interview)
# FAIL in 24.7s
# [6/15] Task apps_2221 (interview)...
# 2026-01-22 23:27:07,816 | INFO | Finished apps_2221 | pass=False tier=L escalations=1 elapsed=32.6s
# INFO:architecture_B:Finished apps_2221 | pass=False tier=L escalations=1 elapsed=32.6s
# 2026-01-22 23:27:07,817 | INFO | Running 7/15 apps_1222 (interview)
# INFO:architecture_B:Running 7/15 apps_1222 (interview)
# FAIL in 32.6s
# [7/15] Task apps_1222 (interview)...
# 2026-01-22 23:27:35,502 | INFO | Finished apps_1222 | pass=False tier=L escalations=1 elapsed=27.7s
# INFO:architecture_B:Finished apps_1222 | pass=False tier=L escalations=1 elapsed=27.7s
# 2026-01-22 23:27:35,506 | INFO | Running 8/15 apps_227 (interview)
# INFO:architecture_B:Running 8/15 apps_227 (interview)
# FAIL in 27.7s
# [8/15] Task apps_227 (interview)...
# 2026-01-22 23:28:02,474 | INFO | Finished apps_227 | pass=False tier=L escalations=1 elapsed=27.0s
# INFO:architecture_B:Finished apps_227 | pass=False tier=L escalations=1 elapsed=27.0s
# 2026-01-22 23:28:02,477 | INFO | Running 9/15 apps_1498 (interview)
# INFO:architecture_B:Running 9/15 apps_1498 (interview)
# FAIL in 27.0s
# [9/15] Task apps_1498 (interview)...
# 2026-01-22 23:28:19,617 | INFO | Finished apps_1498 | pass=True tier=M escalations=0 elapsed=17.1s
# INFO:architecture_B:Finished apps_1498 | pass=True tier=M escalations=0 elapsed=17.1s
# 2026-01-22 23:28:19,620 | INFO | Running 10/15 apps_727 (interview)
# INFO:architecture_B:Running 10/15 apps_727 (interview)
# PASS in 17.1s
# [10/15] Task apps_727 (interview)...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-806853342.py in <cell line: 0>()
#      80
#      81 # Esecuzione
# ---> 82 sample_results = run_sample_tasks(per_level=5, difficulties=("introductory", "interview", "competition"), shuffle=True)
#      83
#      84 # Visualizziamo solo un sommario finale dei risultati invece dell'intera lista
#
# /tmp/ipython-input-806853342.py in run_sample_tasks(per_level, split, difficulties, shuffle)
#      37         start = time.time()
#      38         # Eseguiamo il grafo per il task corrente
# ---> 39         state = run_graph(
#      40             task_id=task.task_id,
#      41             task_description=task.question,
#
# /content/ArchitecturesForCodeDevelopmentWithLLMs/src/graph/graph.py in run_graph(task_id, task_description, test_inputs, test_outputs, architecture)
#     118         test_outputs=test_outputs
#     119     )
# --> 120     return graph.invoke(initial_state)
#
# /usr/local/lib/python3.12/dist-packages/langgraph/pregel/main.py in invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, **kwargs)
#    3069         interrupts: list[Interrupt] = []
#    3070
# -> 3071         for chunk in self.stream(
#    3072             input,
#    3073             config,
#
# /usr/local/lib/python3.12/dist-packages/langgraph/pregel/main.py in stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, subgraphs, debug, **kwargs)
#    2644                     for task in loop.match_cached_writes():
#    2645                         loop.output_writes(task.id, task.writes, cached=True)
# -> 2646                     for _ in runner.tick(
#    2647                         [t for t in loop.tasks.values() if not t.writes],
#    2648                         timeout=self.step_timeout,
#
# /usr/local/lib/python3.12/dist-packages/langgraph/pregel/_runner.py in tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     165             t = tasks[0]
#     166             try:
# --> 167                 run_with_retry(
#     168                     t,
#     169                     retry_policy,
#
# /usr/local/lib/python3.12/dist-packages/langgraph/pregel/_retry.py in run_with_retry(task, retry_policy, configurable)
#      40             task.writes.clear()
#      41             # run the task
# ---> 42             return task.proc.invoke(task.input, config)
#      43         except ParentCommand as exc:
#      44             ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# /usr/local/lib/python3.12/dist-packages/langgraph/_internal/_runnable.py in invoke(self, input, config, **kwargs)
#     654                     # run in context
#     655                     with set_config_context(config, run) as context:
# --> 656                         input = context.run(step.invoke, input, config, **kwargs)
#     657                 else:
#     658                     input = step.invoke(input, config)
#
# /usr/local/lib/python3.12/dist-packages/langgraph/_internal/_runnable.py in invoke(self, input, config, **kwargs)
#     398                 run_manager.on_chain_end(ret)
#     399         else:
# --> 400             ret = self.func(*args, **kwargs)
#     401         if self.recurse and isinstance(ret, Runnable):
#     402             return ret.invoke(input, config)
#
# /content/ArchitecturesForCodeDevelopmentWithLLMs/src/graph/nodes.py in tester_node(state)
#     142
#     143     for i, (test_input, expected_output) in enumerate(zip(test_inputs, test_outputs)):
# --> 144         success, actual_output, error = _execute_code(code, test_input)
#     145
#     146         if not success:
#
# /content/ArchitecturesForCodeDevelopmentWithLLMs/src/graph/nodes.py in _execute_code(code, stdin_input, timeout)
#     195
#     196     try:
# --> 197         result = subprocess.run(
#     198             ['python', temp_path],
#     199             input=stdin_input,
#
# /usr/lib/python3.12/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548     with Popen(*popenargs, **kwargs) as process:
#     549         try:
# --> 550             stdout, stderr = process.communicate(input, timeout=timeout)
#     551         except TimeoutExpired as exc:
#     552             process.kill()
#
# /usr/lib/python3.12/subprocess.py in communicate(self, input, timeout)
#    1207
#    1208             try:
# -> 1209                 stdout, stderr = self._communicate(input, endtime, timeout)
#    1210             except KeyboardInterrupt:
#    1211                 # https://bugs.python.org/issue25942
#
# /usr/lib/python3.12/subprocess.py in _communicate(self, input, endtime, orig_timeout)
#    2113                             'failed to raise TimeoutExpired.')
#    2114
# -> 2115                     ready = selector.select(timeout)
#    2116                     self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    2117
#
# /usr/lib/python3.12/selectors.py in select(self, timeout)
#     413         ready = []
#     414         try:
# --> 415             fd_event_list = self._selector.poll(timeout)
#     416         except InterruptedError:
#     417             return ready
#
# KeyboardInterrupt:

# %%
# !cd log && cat architecture_B.jsonl
# Out:
# {"task_id": "apps_4662", "difficulty": "introductory", "architecture": "B", "test_passed": false, "developer_tier": "L", "escalations": 1, "story_points_initial": 3, "story_points_final": 8, "elapsed_seconds": 20.627573490142822}
# {"task_id": "apps_4471", "difficulty": "introductory", "architecture": "B", "test_passed": false, "developer_tier": "L", "escalations": 1, "story_points_initial": 5, "story_points_final": 8, "elapsed_seconds": 53.0609610080719}
# {"task_id": "apps_4982", "difficulty": "introductory", "architecture": "B", "test_passed": false, "developer_tier": "L", "escalations": 1, "story_points_initial": 5, "story_points_final": 8, "elapsed_seconds": 54.41854405403137}
# {"task_id": "apps_4918", "difficulty": "introductory", "architecture": "B", "test_passed": false, "developer_tier": "L", "escalations": 1, "story_points_initial": 5, "story_points_final": 8, "elapsed_seconds": 33.80232334136963}
# {"task_id": "apps_4108", "difficulty": "introductory", "architecture": "B", "test_passed": false, "developer_tier": "L", "escalations": 2, "story_points_initial": 2, "story_points_final": 8, "elapsed_seconds": 38.98612451553345}
# {"task_id": "apps_2221", "difficulty": "interview", "architecture": "B", "test_passed": false, "developer_tier": "L", "escalations": 1, "story_points_initial": 5, "story_points_final": 8, "elapsed_seconds": 29.38825488090515}
# {"task_id": "apps_1222", "difficulty": "interview", "architecture": "B", "test_passed": false, "developer_tier": "L", "escalations": 1, "story_points_initial": 3, "story_points_final": 8, "elapsed_seconds": 24.924655437469482}
# {"task_id": "apps_227", "difficulty": "interview", "architecture": "B", "test_passed": false, "developer_tier": "L", "escalations": 1, "story_points_initial": 5, "story_points_final": 8, "elapsed_seconds": 27.468550443649292}
# {"task_id": "apps_1498", "difficulty": "interview", "architecture": "B", "test_passed": false, "developer_tier": "L", "escalations": 1, "story_points_initial": 5, "story_points_final": 8, "elapsed_seconds": 31.799286365509033}
# {"task_id": "apps_727", "difficulty": "interview", "architecture": "B", "test_passed": false, "developer_tier": "L", "escalations": 1, "story_points_initial": 3, "story_points_final": 8, "elapsed_seconds": 19.75398302078247}
# {"task_id": "apps_3029", "difficulty": "competition", "architecture": "B", "test_passed": false, "developer_tier": "L", "escalations": 1, "story_points_initial": 5, "story_points_final": 8, "elapsed_seconds": 30.352272033691406}
# {"task_id": "apps_3428", "difficulty": "competition", "architecture": "B", "test_passed": false, "developer_tier": "L", "escalations": 1, "story_points_initial": 5, "story_points_final": 8, "elapsed_seconds": 22.20605492591858}
# {"task_id": "apps_3488", "difficulty": "competition", "architecture": "B", "test_passed": false, "developer_tier": "L", "escalations": 1, "story_points_initial": 3, "story_points_final": 8, "elapsed_seconds": 55.48179864883423}
# {"task_id": "apps_3048", "difficulty": "competition", "architecture": "B", "test_passed": false, "developer_tier": "L", "escalations": 1, "story_points_initial": 5, "story_points_final": 8, "elapsed_seconds": 20.30839467048645}
# {"task_id": "apps_3534", "difficulty": "competition", "architecture": "B", "test_passed": false, "developer_tier": "L", "escalations": 1, "story_points_initial": 5, "story_points_final": 8, "elapsed_seconds": 28.751805067062378}

# %% [markdown]
# ## Evaluation Metrics for Architecture **B**
#
# This section calculates the evaluation metrics as specified in `evaluation.md`:
#
# - **Primary Metrics**: Pass Rate, Pass@1
# - **Cost Metrics**: Execution Time, API Calls
# - **Pass Rate by Difficulty**: Introductory, Interview, Competition

# %%
import pandas as pd
import numpy as np
import json
from pathlib import Path
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns

# Load results from JSONL file
log_file = LOG_DIR / "architecture_B.jsonl"
results = []
if log_file.exists():
    with open(log_file, "r", encoding="utf-8") as f:
        for line in f:
            if line.strip():
                results.append(json.loads(line))
else:
    print(f"Warning: {log_file} not found. Make sure to run the tasks first.")

df = pd.DataFrame(results)
print(f"Loaded {len(df)} task results")

# Mostra tutte le righe
pd.set_option('display.max_rows', None)
df
# Out:
# Loaded 15 task results
#       task_id    difficulty architecture  test_passed developer_tier  \
# 0   apps_4662  introductory            B        False              L
# 1   apps_4471  introductory            B        False              L
# 2   apps_4982  introductory            B        False              L
# 3   apps_4918  introductory            B        False              L
# 4   apps_4108  introductory            B        False              L
# 5   apps_2221     interview            B        False              L
# 6   apps_1222     interview            B        False              L
# 7    apps_227     interview            B        False              L
# 8   apps_1498     interview            B        False              L
# 9    apps_727     interview            B        False              L
# 10  apps_3029   competition            B        False              L
# 11  apps_3428   competition            B        False              L
# 12  apps_3488   competition            B        False              L
# 13  apps_3048   competition            B        False              L
# 14  apps_3534   competition            B        False              L
#
#     escalations  story_points_initial  story_points_final  elapsed_seconds
# 0             1                     3                   8        20.627573
# 1             1                     5                   8        53.060961
# 2             1                     5                   8        54.418544
# 3             1                     5                   8        33.802323
# 4             2                     2                   8        38.986125
# 5             1                     5                   8        29.388255
# 6             1                     3                   8        24.924655
# 7             1                     5                   8        27.468550
# 8             1                     5                   8        31.799286
# 9             1                     3                   8        19.753983
# 10            1                     5                   8        30.352272
# 11            1                     5                   8        22.206055
# 12            1                     3                   8        55.481799
# 13            1                     5                   8        20.308395
# 14            1                     5                   8        28.751805

# %%
# Helper function for Wilson score confidence interval
def wilson_ci(successes, n, confidence=0.95):
    """Calculate Wilson score confidence interval for a proportion."""
    if n == 0:
        return 0, 0, 0
    z = stats.norm.ppf(1 - (1 - confidence) / 2)
    p_hat = successes / n
    denominator = 1 + z**2 / n
    center = (p_hat + z**2 / (2 * n)) / denominator
    margin = z * np.sqrt((p_hat * (1 - p_hat) + z**2 / (4 * n)) / n) / denominator
    return p_hat, center - margin, center + margin

# Calculate Pass Rate
total_tasks = len(df)
passed_tasks = df["test_passed"].sum()
pass_rate = passed_tasks / total_tasks if total_tasks > 0 else 0

# For Architecture B, Pass@1 is the same as Pass Rate (no retries)
pass_at_1 = pass_rate

# Calculate 95% Confidence Interval
p, ci_low, ci_high = wilson_ci(passed_tasks, total_tasks)

print("=" * 60)
print("PRIMARY METRICS - Architecture B (Single-Agent Baseline)")
print("=" * 60)
print(f"\nTotal Tasks Evaluated: {total_tasks}")
print(f"Tasks Passed: {passed_tasks}")
print(f"Pass Rate: {pass_rate:.2%}")
print(f"Pass@1: {pass_at_1:.2%}")
print(f"95% Confidence Interval: [{ci_low:.2%}, {ci_high:.2%}]")
print("=" * 60)
# Out:
# ============================================================
# PRIMARY METRICS - Architecture B (Single-Agent Baseline)
# ============================================================
#
# Total Tasks Evaluated: 15
# Tasks Passed: 0
# Pass Rate: 0.00%
# Pass@1: 0.00%
# 95% Confidence Interval: [0.00%, 20.39%]
# ============================================================

# %%
# Calculate Pass Rate by Difficulty
difficulty_stats = df.groupby("difficulty").agg(
    total=pd.NamedAgg(column="test_passed", aggfunc="count"),
    passed=pd.NamedAgg(column="test_passed", aggfunc="sum")
)
difficulty_stats["pass_rate"] = difficulty_stats["passed"] / difficulty_stats["total"]

# Add 95% CI for each difficulty
cis = []
for _, row in difficulty_stats.iterrows():
    _, ci_l, ci_h = wilson_ci(int(row["passed"]), int(row["total"]))
    cis.append(f"[{ci_l:.2%}, {ci_h:.2%}]")
difficulty_stats["95% CI"] = cis

print("\n" + "=" * 60)
print("PASS RATE BY DIFFICULTY")
print("=" * 60)
print("\n| Difficulty    | Total | Passed | Pass Rate | 95% CI |")
print("|---------------|-------|--------|-----------|--------|")
for diff in ["introductory", "interview", "competition"]:
    if diff in difficulty_stats.index:
        row = difficulty_stats.loc[diff]
        print(f"| {diff:<13} | {int(row['total']):>5} | {int(row['passed']):>6} | {row['pass_rate']:>8.2%} | {row['95% CI']} |")
print("=" * 60)
# Out:
# ============================================================
# PASS RATE BY DIFFICULTY
# ============================================================
#
# | Difficulty    | Total | Passed | Pass Rate | 95% CI |
# |---------------|-------|--------|-----------|--------|
# | introductory  |     5 |      0 |    0.00% | [0.00%, 43.45%] |
# | interview     |     5 |      0 |    0.00% | [0.00%, 43.45%] |
# | competition   |     5 |      0 |    0.00% | [0.00%, 43.45%] |
# ============================================================

# %%
# Calculate Cost Metrics
avg_time = df["elapsed_seconds"].mean()
std_time = df["elapsed_seconds"].std()
median_time = df["elapsed_seconds"].median()
total_time = df["elapsed_seconds"].sum()
min_time = df["elapsed_seconds"].min()
max_time = df["elapsed_seconds"].max()

# For Architecture A, each task is 1 API call (single-agent, no retry)
api_calls_per_task = 1
total_api_calls = total_tasks * api_calls_per_task

print("\n" + "=" * 60)
print("COST METRICS")
print("=" * 60)
print(f"\nExecution Time Statistics:")
print(f"  Average Time per Task: {avg_time:.2f} seconds")
print(f"  Std Dev: {std_time:.2f} seconds")
print(f"  Median Time: {median_time:.2f} seconds")
print(f"  Min Time: {min_time:.2f} seconds")
print(f"  Max Time: {max_time:.2f} seconds")
print(f"  Total Execution Time: {total_time:.2f} seconds ({total_time/60:.2f} minutes)")
print(f"\nAPI Calls:")
print(f"  API Calls per Task: {api_calls_per_task}")
print(f"  Total API Calls: {total_api_calls}")
print("=" * 60)
# Out:
# ============================================================
# COST METRICS
# ============================================================
#
# Execution Time Statistics:
#   Average Time per Task: 32.76 seconds
#   Std Dev: 12.37 seconds
#   Median Time: 29.39 seconds
#   Min Time: 19.75 seconds
#   Max Time: 55.48 seconds
#   Total Execution Time: 491.33 seconds (8.19 minutes)
#
# API Calls:
#   API Calls per Task: 1
#   Total API Calls: 15
# ============================================================

# %%
# Execution Time by Difficulty
time_by_diff = df.groupby("difficulty")["elapsed_seconds"].agg(["mean", "std", "median"])

print("\n" + "=" * 60)
print("EXECUTION TIME BY DIFFICULTY")
print("=" * 60)
print("\n| Difficulty    | Avg Time (s) | Std Dev (s) | Median (s) |")
print("|---------------|--------------|-------------|------------|")
for diff in ["introductory", "interview", "competition"]:
    if diff in time_by_diff.index:
        row = time_by_diff.loc[diff]
        print(f"| {diff:<13} | {row['mean']:>12.2f} | {row['std']:>11.2f} | {row['median']:>10.2f} |")
print("=" * 60)
# Out:
# ============================================================
# EXECUTION TIME BY DIFFICULTY
# ============================================================
#
# | Difficulty    | Avg Time (s) | Std Dev (s) | Median (s) |
# |---------------|--------------|-------------|------------|
# | introductory  |        40.18 |       14.08 |      38.99 |
# | interview     |        26.67 |        4.62 |      27.47 |
# | competition   |        31.42 |       14.10 |      28.75 |
# ============================================================

# %%
# For Architecture A, there are no retries (single-shot)
print("\n" + "=" * 60)
print("RETRY DYNAMICS")
print("=" * 60)
print("\nNote: Architecture A is a single-shot baseline with no retry mechanism.")
print("\n| Retries | Count | Percentage |")
print("|---------|-------|------------|")
print(f"| 0       | {total_tasks:>5} | {100:>10.2f}% |")
print("=" * 60)
# Out:
# ============================================================
# RETRY DYNAMICS
# ============================================================
#
# Note: Architecture A is a single-shot baseline with no retry mechanism.
#
# | Retries | Count | Percentage |
# |---------|-------|------------|
# | 0       |    15 |     100.00% |
# ============================================================

# %%
# Visualizations
sns.set_style("whitegrid")
plt.rcParams["figure.figsize"] = (12, 8)

# Create a figure with subplots
fig, axes = plt.subplots(2, 2, figsize=(14, 10))
fig.suptitle("Architecture A - Evaluation Metrics", fontsize=16, fontweight="bold")

# 1. Pass Rate Bar Chart
ax1 = axes[0, 0]
pass_rate_vals = [difficulty_stats.loc[diff, "pass_rate"] * 100 if diff in difficulty_stats.index else 0 
              for diff in ["introductory", "interview", "competition"]]
colors = ["#2ecc71" if r > 50 else "#e74c3c" for r in pass_rate_vals]
bars = ax1.bar(["Introductory", "Interview", "Competition"], pass_rate_vals, color=colors, edgecolor="black")
ax1.set_ylabel("Pass Rate (%)")
ax1.set_title("Pass Rate by Difficulty")
ax1.set_ylim(0, 100)
for bar, rate in zip(bars, pass_rate_vals):
    ax1.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 2, f"{rate:.1f}%", 
             ha="center", fontsize=11, fontweight="bold")

# 2. Execution Time Box Plot by Difficulty
ax2 = axes[0, 1]
difficulty_order = ["introductory", "interview", "competition"]
df_ordered = df[df["difficulty"].isin(difficulty_order)].copy()
df_ordered["difficulty"] = pd.Categorical(df_ordered["difficulty"], categories=difficulty_order, ordered=True)
sns.boxplot(data=df_ordered, x="difficulty", y="elapsed_seconds", ax=ax2, palette="viridis")
ax2.set_xlabel("Difficulty")
ax2.set_ylabel("Execution Time (seconds)")
ax2.set_title("Execution Time Distribution by Difficulty")

# 3. Pass/Fail Pie Chart
ax3 = axes[1, 0]
labels = ["Passed", "Failed"]
sizes = [passed_tasks, total_tasks - passed_tasks]
colors_pie = ["#2ecc71", "#e74c3c"]
explode = (0.05, 0)
ax3.pie(sizes, explode=explode, labels=labels, colors=colors_pie, autopct="%1.1f%%",
        shadow=True, startangle=90)
ax3.set_title("Overall Pass/Fail Distribution")

# 4. Execution Time Histogram
ax4 = axes[1, 1]
ax4.hist(df["elapsed_seconds"], bins=15, edgecolor="black", color="#3498db", alpha=0.7)
ax4.axvline(avg_time, color="red", linestyle="--", linewidth=2, label=f"Mean: {avg_time:.2f}s")
ax4.axvline(median_time, color="green", linestyle="--", linewidth=2, label=f"Median: {median_time:.2f}s")
ax4.set_xlabel("Execution Time (seconds)")
ax4.set_ylabel("Frequency")
ax4.set_title("Execution Time Distribution")
ax4.legend()

plt.tight_layout()
plt.savefig(LOG_DIR / "architecture_A_metrics.png", dpi=150, bbox_inches="tight")
plt.show()
print(f"\nVisualization saved to: {LOG_DIR / 'architecture_A_metrics.png'}")
# Out:
# /tmp/ipython-input-3595659308.py:27: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df_ordered, x="difficulty", y="elapsed_seconds", ax=ax2, palette="viridis")
# Visualization saved to: /content/ArchitecturesForCodeDevelopmentWithLLMs/log/architecture_A_metrics.png

# %%
# Summary Table
summary_data = {
    "Metric": [
        "Architecture",
        "Total Tasks",
        "Passed Tasks",
        "Pass Rate",
        "Pass@1",
        "95% CI (Lower)",
        "95% CI (Upper)",
        "Avg Execution Time (s)",
        "Std Execution Time (s)",
        "Median Execution Time (s)",
        "Total Execution Time (s)",
        "API Calls per Task",
        "Total API Calls",
        "Retry Count",
        "Escalations"
    ],
    "Value": [
        "A (Single-Agent Baseline)",
        total_tasks,
        passed_tasks,
        f"{pass_rate:.4f}",
        f"{pass_at_1:.4f}",
        f"{ci_low:.4f}",
        f"{ci_high:.4f}",
        f"{avg_time:.2f}",
        f"{std_time:.2f}",
        f"{median_time:.2f}",
        f"{total_time:.2f}",
        api_calls_per_task,
        total_api_calls,
        0,
        0
    ]
}

summary_df = pd.DataFrame(summary_data)
print("\n" + "=" * 60)
print("SUMMARY TABLE FOR ARCHITECTURE A")
print("=" * 60)
print(summary_df.to_string(index=False))
summary_df.to_csv(LOG_DIR / "architecture_A_summary.csv", index=False)

# Save difficulty breakdown
difficulty_summary = difficulty_stats.reset_index()
difficulty_summary.columns = ["Difficulty", "Total", "Passed", "Pass Rate", "95% CI"]
difficulty_summary.to_csv(LOG_DIR / "architecture_A_by_difficulty.csv", index=False)
print(f"\nAll results saved to {LOG_DIR}")
# Out:
# ============================================================
# SUMMARY TABLE FOR ARCHITECTURE A
# ============================================================
#                    Metric                     Value
#              Architecture A (Single-Agent Baseline)
#               Total Tasks                        15
#              Passed Tasks                         0
#                 Pass Rate                    0.0000
#                    Pass@1                    0.0000
#            95% CI (Lower)                    0.0000
#            95% CI (Upper)                    0.2039
#    Avg Execution Time (s)                     32.76
#    Std Execution Time (s)                     12.37
# Median Execution Time (s)                     29.39
#  Total Execution Time (s)                    491.33
#        API Calls per Task                         1
#           Total API Calls                        15
#               Retry Count                         0
#               Escalations                         0
#
# All results saved to /content/ArchitecturesForCodeDevelopmentWithLLMs/log
